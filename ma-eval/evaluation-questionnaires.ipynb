# %% [markdown]
# # Data Evaluation: Demographics

# %% [markdown]
# data preprocessing steps:
# - added column "Whiteboard Experience Codified" (1/0)
# - renamed columns with comparison questions (full question text -> CQ-1/CQ-2/CQ-3/CQ-4)
# - education (B-GE, B-I, ?, M-I, D-I, M-GE, M-BI)

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

data_df = pd.read_csv('../ma-eval/questionnaire-responses-preprocessed.csv')
data_df
# Out:
#              Timestamp Participant ID  Age             Gender  \
# 0   6/29/2026 22:39:09        MA12534   24             Female
# 1    7/7/2026 11:50:30        MA26593   22             Female
# 2    7/1/2026 17:53:04        MA34230   20               Male
# 3   6/30/2026 11:53:04         MA7125   21  Prefer not to say
# 4    7/2/2026 15:56:41        MA95137   26  Prefer not to say
# 5   6/30/2026 16:53:41        MA95935   20             Female
# 6    7/2/2026 13:55:20        MB10509   25               Male
# 7   6/30/2026 13:55:53        MB24145   22               Male
# 8    7/7/2026 16:02:18        MB41880   28               Male
# 9    7/1/2026 11:58:13        MB50964   21             Female
# 10  6/29/2026 22:51:04        MB67500   21               Male
# 11   7/6/2026 11:58:44        MB71184   32               Male
# 12   7/7/2026 14:48:41        PA38184   24  Prefer not to say
# 13  6/29/2026 22:43:30        PA40344   19               Male
# 14   7/2/2026 11:50:26         PA4076   21               Male
# 15  6/30/2026 12:51:30        PA45003   19               Male
# 16   7/1/2026 11:02:06        PA81918   27               Male
# 17   7/6/2026 10:53:04        PA89964   26               Male
# 18   7/6/2026 12:56:10         PB3394   24               Male
# 19  6/30/2026 15:50:46        PB34703   20               Male
# 20   7/2/2026 14:57:45        PB46220   20             Female
# 21   7/7/2026 17:00:47        PB47107   29  Prefer not to say
# 22   7/1/2026 14:55:33        PB50308   28               Male
# 23  6/30/2026 10:51:27        PB54700   28               Male
#
#      Education (study course and whether its ongoing) Education Codified  \
# 0                        Bachelor (Games Engineering)               B-GE
# 1   B.Sc. Informatics: Games Engineering (complete...           B-GE B-I
# 2                             B.Sc. Games Engineering               B-GE
# 3                                             ongoing                  ?
# 4                Bachelor Games Engineering (ongoing)               B-GE
# 5                                    ongoing bachelor                  ?
# 6                       M.Sc. Informatics (completed)                M-I
# 7                                             ongoing                  ?
# 8                       Currently in msc. informatics                M-I
# 9               B.Sc. Games Engineering, 4th semester               B-GE
# 10                 B. Sc. Games Engineering (ongoing)               B-GE
# 11                    Doctoral Student in Informatics                D-I
# 12                 Master Games Engineering (ongoing)               M-GE
# 13  Abitur (currently enrolled at TUM B.Sc. Inform...               B-GE
# 14      Informatics: Games engineering (4th semester)               B-GE
# 15                                  ongoing, Bachelor                  ?
# 16                              Master Bioinformatics               M-BI
# 17              Informatics: Games Engineering, M.Sc.               M-GE
# 18    ongoing Master in Informatik: Games Engineering               M-GE
# 19                                            ongoing                  ?
# 20                                  Games Engineering               B-GE
# 21                            Msc Informatik, ongoing                M-I
# 22                         Doctorate Computer Science                D-I
# 23                 Games engineering Master (ongoing)               M-GE
#
#                                Occupation:  \
# 0                                  Student
# 1                                  Student
# 2                                  Student
# 3                            Student, HiWi
# 4                                  Student
# 5                                  Student
# 6                               unemployed
# 7                                 Student
# 8                         student, web dev
# 9                                  student
# 10                                 Student
# 11                        Doctoral Student
# 12                             TA, Student
# 13                                 Student
# 14                                 student
# 15                                   tutor
# 16                       Software Engineer
# 17            Game/Software Developer (VR)
# 18                                 Student
# 19                                 student
# 20                                 Student
# 21                 Student/Working Student
# 22                     Scientific Employee
# 23  Student / Game developer (Werkstudent)
#
#    Number of projects/games you worked on (rough estimate)  Projects Codified  \
# 0                                                   5                       5
# 1                                                   1                       1
# 2                                                   3                       3
# 3                                                   1                       1
# 4   5+ (but always only small projects for uni or ...                       5
# 5                            completed: 5, ongoing: 3                       5
# 6                                                   3                       3
# 7                                                 4-5                       5
# 8                                                   3                       3
# 9                                                   5                       5
# 10                                                  5                       5
# 11                                                  4                       4
# 12                                                 10                      10
# 13                                                  5                       5
# 14                                                  6                       6
# 15                                                  5                       5
# 16                     10 (software only, mostly OSS)                      10
# 17                                              10-20                      10
# 18                                                 10                      10
# 19                                                  4                       4
# 20                       complete: 5, non-complete: 4                       5
# 21                             4,  non gaming related                       4
# 22                                                  7                       7
# 23                                                 25                      25
#
#    Experience with digital whiteboards (e.g. Miro, Figjam)  ...  UEQS-4  \
# 0                                           used Miro       ...       3
# 1                                                 NaN       ...       3
# 2                                   Miro and Milanote       ...       6
# 3           not those examples, but I used "FreeForm"       ...       6
# 4                                      basically none       ...       2
# 5                                                Miro       ...       7
# 6                                                none       ...       7
# 7                                      fast gar keine       ...       3
# 8                                  non zero but close       ...       4
# 9          mediocre, not new but also not experienced       ...       5
# 10                                     Miro, Milanote       ...       2
# 11                                                yes       ...       6
# 12                                                 no       ...       2
# 13                                     Miro, Milanote       ...       7
# 14  I've used Miro and Trello for group projects a...       ...       2
# 15                                               Miro       ...       6
# 16                                              basic       ...       6
# 17        Using Miro regularly for personal projects.       ...       5
# 18                       lots of experience with Miro       ...       6
# 19                    Miro, Figma aber nicht soo viel       ...       5
# 20                   none (but familiar with concept)       ...       5
# 21                                               none       ...       3
# 22                                                NaN       ...       3
# 23  Used miro in a few projects, used miroboard a ...       ...       3
#
#    UEQS-5  UEQS-6 UEQS-7  UEQS-8  C-Q1  C-Q2  C-Q3  C-Q4  \
# 0       6       7      7       7     3     1     2     4
# 1       5       6      7       6     3     4     4     4
# 2       6       6      7       7     2     4     4     5
# 3       5       7      5       5     5     4     5     5
# 4       7       7      6       5     5     4     4     5
# 5       7       7      4       4     5     5     5     5
# 6       7       7      5       5     3     5     5     4
# 7       6       6      4       5     4     4     4     4
# 8       3       5      2       2     2     1     4     3
# 9       7       7      6       6     4     4     4     5
# 10      6       6      5       5     2     2     4     3
# 11      6       6      4       4     5     5     5     5
# 12      7       7      4       4     1     5     5     2
# 13      5       6      5       5     5     4     5     5
# 14      4       5      6       6     2     4     3     5
# 15      5       5      4       6     5     5     5     5
# 16      4       4      2       5     2     2     2     5
# 17      4       5      6       5     4     5     4     3
# 18      3       5      6       6     2     2     2     2
# 19      4       6      4       3     2     2     4     4
# 20      6       6      4       4     3     4     5     3
# 21      4       7      6       6     3     3     4     5
# 22      5       7      6       6     3     4     2     4
# 23      5       6      7       5     2     3     2     2
#
#                                                   FQ2
# 0                                                 NaN
# 1                                                 NaN
# 2         The locks need to be differentiable by look
# 3                                                 NaN
# 4   It's nice to use but it takes some time to get...
# 5   Would have liked to have a "total time needed ...
# 6   Tool did not make it clear which locks had whi...
# 7   Please for gods sake put more contrast between...
# 8   I feel like so much potential is wasted not in...
# 9   i wasn't really sure what happened in the path...
# 10                                                NaN
# 11  I would have liked to be able to interact more...
# 12                                                NaN
# 13                                                NaN
# 14  Probably the biggest issue that I had was the ...
# 15                                                NaN
# 16  it's easy to accidentally moving nodes; zoomin...
# 17  When getting a path from one node to another, ...
# 18  in miro i liked that i could see the number of...
# 19  It was way easier to tell the type of a lock i...
# 20  The nodes are hard to distinguish from the bac...
# 21  In its current state the system lacks clear in...
# 22  More functionality would be nice: Better visua...
# 23  The tool definately has great potential, but t...
#
# [24 rows x 38 columns]

# %% [markdown]
# ## Basic Distributions

# %%
data_df['Age'].hist()
# Out:
# <Axes: >

# %%
data_df['Age'].describe()
# Out:
# count    24.000000
# mean     23.625000
# std       3.669054
# min      19.000000
# 25%      20.750000
# 50%      23.000000
# 75%      26.250000
# max      32.000000
# Name: Age, dtype: float64

# %%
gender_counts = data_df['Gender'].value_counts(normalize=True)
plot = gender_counts.plot.pie(y="count", figsize=(5, 5))

# %%
edu_counts = data_df['Education Codified'].value_counts(normalize=True)
plot = edu_counts.plot.pie(y="count", figsize=(5, 5))

# %%
whiteboard_counts = data_df['Whiteboard Experience Codified'].value_counts(normalize=True)
plot = whiteboard_counts.plot.pie(y="count", figsize=(5, 5))

# %%
data_df['Whiteboard Experience Codified'].hist()
# Out:
# <Axes: >

# %%
whiteboard_counts
# Out:
# Whiteboard Experience Codified
# 1    0.625
# 0    0.375
# Name: proportion, dtype: float64

# %%
data_df[['Age', 'Whiteboard Experience Codified']].corr()
# Out:
#                                      Age  Whiteboard Experience Codified
# Age                             1.000000                       -0.272566
# Whiteboard Experience Codified -0.272566                        1.000000

# %%
ax1 = data_df.boxplot(column=['Age'], by='Whiteboard Experience Codified')

# %%
project_counts = data_df['Projects Codified'].hist()

# %%
data_df[['Whiteboard Experience Codified', 'Projects Codified']].corr()
# Out:
#                                 Whiteboard Experience Codified  \
# Whiteboard Experience Codified                        1.000000
# Projects Codified                                     0.216461
#
#                                 Projects Codified
# Whiteboard Experience Codified           0.216461
# Projects Codified                        1.000000

# %% [markdown]
# ## Miro Comparison Questions

# %% [markdown]
# 1. Compared to Miro, the system made it easier to analyze dungeon designs.
# 2. Compared to Miro, I felt more confident in my answers.
# 3. Compared to Miro, I was able to complete the tasks more efficiently.
# 4. If I were analyzing game levels in practice, I would prefer using the system over a general-purpose whiteboard

# %%
comparison_columns = [
    "C-Q1",
    "C-Q2",
    "C-Q3",
    "C-Q4"
]

compared_df = data_df[comparison_columns]
compared_df
# Out:
#     C-Q1  C-Q2  C-Q3  C-Q4
# 0      3     1     2     4
# 1      3     4     4     4
# 2      2     4     4     5
# 3      5     4     5     5
# 4      5     4     4     5
# 5      5     5     5     5
# 6      3     5     5     4
# 7      4     4     4     4
# 8      2     1     4     3
# 9      4     4     4     5
# 10     2     2     4     3
# 11     5     5     5     5
# 12     1     5     5     2
# 13     5     4     5     5
# 14     2     4     3     5
# 15     5     5     5     5
# 16     2     2     2     5
# 17     4     5     4     3
# 18     2     2     2     2
# 19     2     2     4     4
# 20     3     4     5     3
# 21     3     3     4     5
# 22     3     4     2     4
# 23     2     3     2     2

# %%
compared_df.describe()
# Out:
#             C-Q1       C-Q2       C-Q3       C-Q4
# count  24.000000  24.000000  24.000000  24.000000
# mean    3.208333   3.583333   3.875000   4.041667
# std     1.284664   1.282547   1.115601   1.082636
# min     1.000000   1.000000   2.000000   2.000000
# 25%     2.000000   2.750000   3.750000   3.000000
# 50%     3.000000   4.000000   4.000000   4.000000
# 75%     4.250000   4.250000   5.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000

# %%
compared_df.boxplot()
# Out:
# <Axes: >

# %%
data_df.hist(column=comparison_columns, bins=np.arange(0,6)+0.5, grid=False, layout=(1, 4), figsize=(15, 3))
# Out:
# array([[<Axes: title={'center': 'C-Q1'}>,
#         <Axes: title={'center': 'C-Q2'}>,
#         <Axes: title={'center': 'C-Q3'}>,
#         <Axes: title={'center': 'C-Q4'}>]], dtype=object)

# %%
data_df.boxplot(column=comparison_columns, by='Whiteboard Experience Codified')
# Out:
# array([[<Axes: title={'center': 'C-Q1'}, xlabel='Whiteboard Experience Codified'>,
#         <Axes: title={'center': 'C-Q2'}, xlabel='Whiteboard Experience Codified'>],
#        [<Axes: title={'center': 'C-Q3'}, xlabel='Whiteboard Experience Codified'>,
#         <Axes: title={'center': 'C-Q4'}, xlabel='Whiteboard Experience Codified'>]],
#       dtype=object)

# %% [markdown]
# ### Compared to Miro, the system made it easier to analyze dungeon designs.

# %%
compared_df["C-Q1"].hist(bins=np.arange(0,6)+0.5, grid=False)
# Out:
# <Axes: >

# %%
data_df.hist(column=["C-Q1"], bins=np.arange(0,6)+0.5, grid=False, by="Whiteboard Experience Codified")
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)

# %% [markdown]
# ### Compared to Miro, I felt more confident in my answers.

# %%
compared_df["C-Q2"].hist(bins=np.arange(0,6)+0.5, grid=False)
# Out:
# <Axes: >

# %%
data_df.hist(column=["C-Q2"], bins=np.arange(0,6)+0.5, grid=False, by="Whiteboard Experience Codified")
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)

# %% [markdown]
# ### Compared to Miro, I was able to complete the tasks more efficiently.

# %%
compared_df["C-Q3"].hist(bins=np.arange(0,6)+0.5, grid=False)
# Out:
# <Axes: >

# %%
data_df.hist(column=["C-Q3"], bins=np.arange(0,6)+0.5, grid=False, by="Whiteboard Experience Codified")
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)

# %% [markdown]
# ### Compared to Miro, I was able to complete the tasks more efficiently.

# %%
compared_df["C-Q4"].hist(bins=np.arange(0,6)+0.5, grid=False)
# Out:
# <Axes: >

# %%
data_df.hist(column=["C-Q4"], bins=np.arange(0,6)+0.5, grid=False, by="Whiteboard Experience Codified")
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)

# %% [markdown]
# ### Answer Distributions By Whiteboard Experience

# %%
from scipy.stats import wilcoxon, mannwhitneyu, levene
import numpy as np
np.set_printoptions(legacy='1.25')

# %%
data_exp_yes = data_df.loc[data_df['Whiteboard Experience Codified'] == 1]
data_exp_no = data_df.loc[data_df['Whiteboard Experience Codified'] == 0]

# %% [markdown]
# #### C-Q1

# %% [markdown]
# *x*: C-Q1 answers *with* whiteboard experience
#
# *y*: C-Q1 *without* whiteboard experience
#
# $H_0$: the distribution underlying x is not stochastically greater than (i.e. is smaller than or equal to) the distribution underlying y
#
# $H_{alt}$: the distribution underlying x is stochastically greater than the distribution underlying y, i.e. SX(u) > SY(u) for all u

# %%
mwu_c_q1_wb_exp = mannwhitneyu(data_exp_yes['C-Q1'], data_exp_no['C-Q1'], alternative='less')
mwu_c_q1_wb_exp.statistic, mwu_c_q1_wb_exp.pvalue
# Out:
# (72.5, 0.6330103432972131)

# %%
data_exp_yes['C-Q1'].median()
# Out:
# 3.0

# %%
data_exp_no['C-Q1'].median()
# Out:
# 3.0

# %%
lev_c_q1_wb_exp = levene(data_exp_yes['C-Q1'], data_exp_no['C-Q1'])
lev_c_q1_wb_exp.statistic, lev_c_q1_wb_exp.pvalue
# Out:
# (4.074695121951221, 0.05588339886619132)

# %% [markdown]
# #### C-Q2

# %% [markdown]
# *x*: C-Q2 answers *with* whiteboard experience
#
# *y*: C-Q2 *without* whiteboard experience
#
# $H_0$: the distribution underlying x is not stochastically greater than (i.e. is smaller than or equal to) the distribution underlying y
#
# $H_{alt}$: the distribution underlying x is stochastically greater than the distribution underlying y, i.e. SX(u) > SY(u) for all u

# %%
mwu_c_q2_wb_exp = mannwhitneyu(data_exp_yes['C-Q2'], data_exp_no['C-Q2'], alternative='less')
mwu_c_q2_wb_exp.statistic, mwu_c_q2_wb_exp.pvalue
# Out:
# (60.5, 0.3420826661760219)

# %%
data_exp_yes['C-Q2'].median()
# Out:
# 4.0

# %%
data_exp_no['C-Q2'].median()
# Out:
# 4.0

# %%
lev_c_q2_wb_exp = levene(data_exp_yes['C-Q2'], data_exp_no['C-Q2'])
lev_c_q2_wb_exp.statistic, lev_c_q2_wb_exp.pvalue
# Out:
# (0.9458598726114652, 0.3413479699753748)

# %% [markdown]
# #### C-Q3

# %% [markdown]
# *x*: C-Q3 answers *with* whiteboard experience
#
# *y*: C-Q3 *without* whiteboard experience
#
# $H_0$: the distribution underlying x is not stochastically greater than (i.e. is smaller than or equal to) the distribution underlying y
#
# $H_{alt}$: the distribution underlying x is stochastically greater than the distribution underlying y, i.e. SX(u) > SY(u) for all u

# %%
mwu_c_q3_wb_exp = mannwhitneyu(data_exp_yes['C-Q3'], data_exp_no['C-Q3'], alternative='less')
mwu_c_q3_wb_exp.statistic, mwu_c_q3_wb_exp.pvalue
# Out:
# (58.0, 0.28396903114234606)

# %%
data_exp_yes['C-Q3'].median()
# Out:
# 4.0

# %%
data_exp_no['C-Q3'].median()
# Out:
# 4.0

# %%
lev_c_q3_wb_exp = levene(data_exp_yes['C-Q3'], data_exp_no['C-Q3'])
lev_c_q3_wb_exp.statistic, lev_c_q3_wb_exp.pvalue
# Out:
# (1.342483108108108, 0.2590195018943345)

# %% [markdown]
# #### C-Q4

# %% [markdown]
# *x*: C-Q4 answers *with* whiteboard experience
#
# *y*: C-Q4 *without* whiteboard experience
#
# $H_0$: the distribution underlying x is not stochastically greater than (i.e. is smaller than or equal to) the distribution underlying y
#
# $H_{alt}$: the distribution underlying x is stochastically greater than the distribution underlying y, i.e. SX(u) > SY(u) for all u

# %%
mwu_c_q4_wb_exp = mannwhitneyu(data_exp_yes['C-Q4'], data_exp_no['C-Q4'], alternative='greater')
mwu_c_q4_wb_exp.statistic, mwu_c_q4_wb_exp.pvalue
# Out:
# (87.0, 0.11397889086301405)

# %%
data_exp_yes['C-Q4'].median()
# Out:
# 5.0

# %%
data_exp_no['C-Q4'].median()
# Out:
# 4.0

# %%
lev_c_q4_wb_exp = levene(data_exp_yes['C-Q4'], data_exp_no['C-Q4'])
lev_c_q4_wb_exp.statistic, lev_c_q4_wb_exp.pvalue
# Out:
# (0.09821428571428581, 0.7569351000940435)
