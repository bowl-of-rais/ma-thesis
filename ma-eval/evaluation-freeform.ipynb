# %% [markdown]
# # Data Evaluation: Freeform Feedback

# %% [markdown]
# ## From Questionnaires

# %% [markdown]
# **FQ1**: Was there anything about the modeling interface that you found confusing or frustrating?
#
# **FQ2**: Anything else you want to tell us?

# %%
import pandas as pd
import matplotlib as mpl
# %matplotlib inline

q_data_df = pd.read_csv('../ma-eval/questionnaire-responses-preprocessed.csv')
p_data_df = pd.read_csv('../ma-eval/feedback-comments-observations.csv')

# %%
fq1_df = q_data_df[['Participant ID','FQ1']][q_data_df['FQ1'].notnull()]
print(*fq1_df['FQ1'].to_list(), sep='\n- ')
# Out:
# There were a lot of options for components/doors of which I sometimes what confused which door was the correct one to choose. But could've been on purpose to have choices.
# - I often had to double-click on an object, like a button or an edge, in order to activate it or change its properties.
# - No Enter to get from Node Name to Description, No Shift + Enter in Node Description to confirm Node and add it
# - I didn't see where I could add locks
# - I was to dumb to figure out how to add a key, also the right click context actions could be more consistent
# - At first it was unclear how to add components (enemies, keys) since editing the node doesnt work, the little dropdown arrow needs to be used. Adding doors etc to edges was confusing at first. For the small map from these tasks, laying out nodes was acceptable, but already slightly frustrating (avoiding overlap, making space for new nodes, ...).
# ...

# %%
fq2_df = q_data_df[['Participant ID','FQ2']][q_data_df['FQ2'].notnull()]
print(*fq2_df['FQ2'].to_list(), sep='\n- ')
# Out:
# The locks need to be differentiable by look
# - It's nice to use but it takes some time to get used to imo
# - Would have liked to have a "total time needed to reach room n" when selecting a path. Also it was slightly confusing that the diagramme didn't show the rooms on the path in order on its x axis.
# - Tool did not make it clear which locks had which type (UI issue). I felt confident answering questions for the "direct" path, but manual intervention would be required to analyze indirect paths. Thus I did not feel confident answering questions in full generality.
# - Please for gods sake put more contrast between the nodes/the graphical outline of the nodes and the background it is very difficult to exactly see the nodes which lead to some confusion on my part
# ...

# %% [markdown]
# ## From Protocols

# %%
p_data_df
# Out:
#        p_id group  tag                                               note
# 0   PA40344    AP  IFB                             nice tool to work with
# 1   PA40344    AP  IFB                                   movement/unclear
# 2   PA40344    AP  IFB                                    would use again
# 3   PA40344    AP  OFP                             successive pathfinding
# 4    MA7125    AM  CFP                     unsure where pathfinding fails
# 5    MA7125    AM  CFP                   bigger node titles would be nice
# 6    MA7125    AM  CFP                        sum of values would be nice
# 7    MA7125    AM  CFP                      baseline in diagrams not at 0
# 8    MA7125    AM  CLG                      enemies respawn (miro, first)
# 9    MA7125    AM  CAM                         hard to keep track of keys
# 10  MA26593    AM  OFP                             successive pathfinding
# 11  MA26593    AM  CLG                     same symbol for all lock types
# ...

# %% [markdown]
# - 3 participants expressed difficulty with answering pacing questions/doing required calculations based on Miro modeling
# - 5 participants required clarification that all locks were visualized by the same symbol (4 of them completed the task in Miro first)
# - 2 feedbacked verbally that locks should be visually differentiated
# - 10 participants did some form of successive pathfinding in pix:e

# %% [markdown]
# ---
