# %% [markdown]
# # Data Evaluation: User Study

# %% [markdown]
# ## 0. Setup

# %%
import pandas as pd
import matplotlib as mpl

data_df = pd.read_csv('../eval-toolchain/eval-data.csv')
data_df
# Out:
#     participant     p_id        date group  s_issues_miro  s_issues_pixie  \
# 0             2  PA40344  2026-06-29    AP              5               3
# 1             5   MA7125  2026-06-30    AM              2               3
# 2             6  PA45003  2026-06-30    AP              2               1
# 3             4  PB54700  2026-06-30    BP              3               2
# 4             7  MB24145  2026-06-30    BM              3               2
# 5            11  MB50964         NaN    BM              2               4
# 6            10  PA81918         NaN    AP              6               3
# 7             1  MA12534  2026-06-29    AM              3               0
# 8             9  MA95935  2026-06-30    AM              2               0
# 9             8  PB34703  2026-06-30    BP              2               4
# 10            3  MB67500  2026-06-29    BM              6               3
#
#     s_issues_correct_miro  s_issues_correct_pixie  p_answered_miro  \
# 0                     NaN                     NaN                6
# 1                     NaN                     NaN                2
# 2                     NaN                     NaN                3
# 3                     NaN                     NaN                2
# 4                     NaN                     NaN                1
# 5                     NaN                     NaN                1
# 6                     NaN                     NaN                2
# 7                     NaN                     NaN                2
# 8                     NaN                     NaN                2
# 9                     NaN                     NaN                6
# 10                    NaN                     NaN                4
#
#     p_answered_pixie  p_answered_correct_miro  p_answered_correct_pixie
# 0                  6                      NaN                       NaN
# 1                  3                      NaN                       NaN
# 2                  4                      NaN                       NaN
# 3                  1                      NaN                       NaN
# 4                  4                      NaN                       NaN
# 5                  2                      NaN                       NaN
# 6                  4                      NaN                       NaN
# 7                  3                      NaN                       NaN
# 8                  2                      NaN                       NaN
# 9                  4                      NaN                       NaN
# 10                 5                      NaN                       NaN

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### Group Distribution

# %%
group_counts = data_df['group'].value_counts(normalize=True)
plot = group_counts.plot.pie(y="count", figsize=(5, 5))
